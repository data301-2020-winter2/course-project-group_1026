# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from Scripts import project_functions # This is called a relative import
df = project_functions.load_and_process("acs2017_county_data.csv")
df
# Out:
#      CountyId       State            County  TotalPop     Men   Women  \
# 0        6001  California    Alameda County   1629615  799649  829966
# 1        6003  California     Alpine County      1203     664     539
# 2        6005  California     Amador County     37306   20005   17301
# 3        6007  California      Butte County    225207  111587  113620
# 4        6009  California  Calaveras County     45057   22292   22765
# ..        ...         ...               ...       ...     ...     ...
# 436     48499       Texas       Wood County     43315   21523   21792
# 437     48501       Texas     Yoakum County      8481    4286    4195
# 438     48503       Texas      Young County     18166    8922    9244
# 439     48505       Texas     Zapata County     14415    7190    7225
# 440     48507       Texas     Zavala County     12152    6163    5989
#
#      Hispanic  White  Black  Native  ...  Production  OtherTransp  WorkAtHome  \
# 0        22.5   32.2   10.7     0.3  ...         9.2          3.6         6.0
# 1         9.7   64.6    1.5    20.6  ...         8.3          1.6        14.0
# 2        13.2   79.3    2.0     0.7  ...        10.1          1.1         6.4
# 3        15.7   72.9    1.5     0.7  ...        10.1          3.9         5.7
# 4        11.5   82.0    0.6     0.9  ...        11.5          0.6         8.3
# ..        ...    ...    ...     ...  ...         ...          ...         ...
# 436       9.6   83.2    5.5     0.6  ...        14.1          1.0         5.6
# 437      65.0   33.2    0.0     0.2  ...        14.4          0.2         1.3
# 438      18.1   78.8    1.5     0.5  ...        13.7          1.4         6.1
# 439      94.1    5.2    0.0     0.0  ...        20.2          0.6         2.0
# 440      93.6    5.4    0.5     0.1  ...        15.3          4.2         5.4
#
#      MeanCommute  Employed  PrivateWork  PublicWork  SelfEmployed  FamilyWork  \
# 0           32.5    826310         79.3        13.2           7.3         0.1
# 1           21.9       374         58.6        30.2          11.2         0.0
# 2           32.0     13444         63.9        21.0          14.7         0.4
# 3           20.1     93439         72.8        17.2           9.7         0.4
# 4           35.5     16721         67.6        18.2          13.7         0.4
# ..           ...       ...          ...         ...           ...         ...
# 436         30.2     15960         78.4        14.1           7.1         0.4
# 437         16.2      3755         71.7        17.5          10.7         0.1
# 438         15.3      8248         69.8        17.1          11.9         1.2
# 439         18.2      5146         66.0        21.0          12.6         0.4
# 440         13.7      4397         73.9        21.2           4.9         0.1
#
#      Unemployment
# 0             6.0
# 1            14.6
# 2             9.3
# 3             9.1
# 4             7.1
# ..            ...
# 436           7.8
# 437           7.5
# 438           4.5
# 439          12.4
# 440          10.1
#
# [441 rows x 29 columns]

# %%
percent_form =['Men','Women']
df[percent_form]=df[percent_form].div(df["TotalPop"], axis="index")*100
df.head()
# Out:
#    CountyId       State            County  TotalPop        Men      Women  \
# 0      6001  California    Alameda County   1629615  49.069811  50.930189
# 1      6003  California     Alpine County      1203  55.195345  44.804655
# 2      6005  California     Amador County     37306  53.624082  46.375918
# 3      6007  California      Butte County    225207  49.548637  50.451363
# 4      6009  California  Calaveras County     45057  49.475109  50.524891
#
#    Hispanic  White  Black  Native  ...  Production  OtherTransp  WorkAtHome  \
# 0      22.5   32.2   10.7     0.3  ...         9.2          3.6         6.0
# 1       9.7   64.6    1.5    20.6  ...         8.3          1.6        14.0
# 2      13.2   79.3    2.0     0.7  ...        10.1          1.1         6.4
# 3      15.7   72.9    1.5     0.7  ...        10.1          3.9         5.7
# 4      11.5   82.0    0.6     0.9  ...        11.5          0.6         8.3
#
#    MeanCommute  Employed  PrivateWork  PublicWork  SelfEmployed  FamilyWork  \
# 0         32.5    826310         79.3        13.2           7.3         0.1
# 1         21.9       374         58.6        30.2          11.2         0.0
# 2         32.0     13444         63.9        21.0          14.7         0.4
# 3         20.1     93439         72.8        17.2           9.7         0.4
# 4         35.5     16721         67.6        18.2          13.7         0.4
#
#    Unemployment
# 0           6.0
# 1          14.6
# 2           9.3
# 3           9.1
# 4           7.1
#
# [5 rows x 29 columns]

# %%
df.describe(exclude=np.object).T
# Out:
#                  count           mean            std           min  \
# CountyId         441.0   35492.684807   17083.051102   6001.000000
# TotalPop         441.0  241449.283447  693148.227348     74.000000
# Men              441.0      50.784517       3.124519     45.444319
# Women            441.0      49.215483       3.124519     32.037325
# Hispanic         441.0      26.996825      22.393134      1.500000
# White            441.0      61.559864      21.608888      0.600000
# Black            441.0       6.901814       7.443716      0.000000
# Native           441.0       0.521769       1.336473      0.000000
# Asian            441.0       2.126757       4.176929      0.000000
# Pacific          441.0       0.091156       0.243065      0.000000
# Income           441.0   52126.344671   13627.602260  24794.000000
# IncomeErr        441.0    3652.192744    3571.113173    262.000000
# IncomePerCap     441.0   26380.904762    6959.601627  12543.000000
# IncomePerCapErr  441.0    1652.573696    1594.750753    129.000000
# Poverty          441.0      16.054422       5.534720      2.800000
# ChildPoverty     441.0      22.462132       9.106596      0.000000
# Professional     441.0      31.202721       6.846136     14.000000
# Production       441.0      13.151020       4.703983      0.000000
# OtherTransp      441.0       1.748753       1.464350      0.000000
# WorkAtHome       441.0       4.527211       2.483259      0.000000
# MeanCommute      441.0      24.191837       5.766011      7.700000
# Employed         441.0  111494.750567  330262.742344     39.000000
# PrivateWork      441.0      73.722449       7.133625     43.600000
# PublicWork       441.0      17.734694       5.944095      7.500000
# SelfEmployed     441.0       8.270295       3.216068      0.000000
# FamilyWork       441.0       0.271655       0.426443      0.000000
# Unemployment     441.0       6.663719       2.768327      0.000000
#
#                           25%           50%            75%           max
# CountyId         12105.000000  48067.000000   48287.000000  4.850700e+04
# TotalPop         12972.000000  40544.000000  155719.000000  1.010572e+07
# Men                 49.069811     49.813251      51.328904  6.796267e+01
# Women               48.671096     50.186749      50.930189  5.455568e+01
# Hispanic             9.600000     20.600000      39.200000  9.920000e+01
# White               47.200000     64.800000      77.600000  9.580000e+01
# Black                1.500000      4.500000       9.700000  5.530000e+01
# Native               0.100000      0.200000       0.500000  2.060000e+01
# Asian                0.300000      0.800000       1.900000  3.490000e+01
# Pacific              0.000000      0.000000       0.100000  3.400000e+00
# Income           43529.000000  50000.000000   57813.000000  1.067610e+05
# IncomeErr         1546.000000   2698.000000    4541.000000  3.245500e+04
# IncomePerCap     22152.000000  25461.000000   29693.000000  6.952900e+04
# IncomePerCapErr    695.000000   1248.000000    2007.000000  1.317500e+04
# Poverty             12.600000     15.700000      18.700000  4.150000e+01
# ChildPoverty        16.600000     22.000000      27.200000  6.230000e+01
# Professional        26.500000     30.600000      34.500000  6.000000e+01
# Production           9.800000     13.200000      16.100000  4.870000e+01
# OtherTransp          1.000000      1.400000       2.100000  1.080000e+01
# WorkAtHome           2.900000      4.100000       5.700000  1.810000e+01
# MeanCommute         20.100000     23.800000      28.000000  4.420000e+01
# Employed          4770.000000  16629.000000   68640.000000  4.805817e+06
# PrivateWork         70.100000     74.900000      78.500000  8.650000e+01
# PublicWork          13.600000     16.600000      20.400000  4.770000e+01
# SelfEmployed         6.000000      7.600000       9.800000  2.040000e+01
# FamilyWork           0.100000      0.200000       0.300000  6.100000e+00
# Unemployment         5.100000      6.400000       7.900000  2.630000e+01

# %%
df.describe(exclude=np.number).T
# Out:
#        count unique            top freq
# State    441      4          Texas  254
# County   441    409  Orange County    4

# %%
ax = sns.boxplot(y="Income", x ="State", data = df).set_title("Income vs States Comparison")
fig = ax.get_figure()
fig.savefig("images/fig1.png")

# %%
ax = sns.barplot(x = "State", y = "TotalPop",data = df).set_title("Total population of each state")
fix = ax.get_figure()
fig.savefig("images/fig2.png")

# %%
class color:
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

# %%
ax = sns.boxplot(y="IncomePerCap", x ="State", data = df).set_title("Income Per Capita vs States Comparison")
fig = ax.get_figure()
fig.savefig("images/fig3.png")

print(color.BOLD + "This seems more valid as income per capita is the measure of amount of money earned per person rather than of the state as a whole" + color.END)
print(color.BOLD +"As seen the population of all of these 4 states are quite different in size checking the income of a state as whole doesn't make sense"+ color.END)


print(color.BOLD + color.UNDERLINE + "ineteresting how the income per cap for California and New York are similar" + color.END)
print(color.BOLD + color.UNDERLINE +"Similarly, income per capita for Texas and Florida are similar" + color.END)
# Out:
# This seems more valid as income per capita is the measure of amount of money earned per person rather than of the state as a whole
# As seen the population of all of these 4 states are quite different in size checking the income of a state as whole doesn't make sense
# ineteresting how the income per cap for California and New York are similar
# Similarly, income per capita for Texas and Florida are similar

# %%
print(df[['Poverty','ChildPoverty']].corr())

print(color.BOLD + "Not Suprisingly Child Poverty Rate and Poverty Rates are correlated" + color.END)
# Out:
#                Poverty  ChildPoverty
# Poverty       1.000000      0.904335
# ChildPoverty  0.904335      1.000000
# Not Suprisingly Child Poverty Rate and Poverty Rates are correlated

# %%
ax = sns.barplot(x=df['State'],y=df['Poverty']).set_title("Poverty Rate per State")
fig = ax.get_figure()
fig.savefig("images/fig4.png")
