# %%
import pandas as pd
import numpy as np

# %%
def load_and_process(url_or_path_to_csv_file):
    

    df1 = (
        pd.read_csv(url_or_path_to_csv_file)
        .dropna()
        .drop(['VotingAgeCitizen','Office','Drive','Carpool','Transit','Walk','Service','Construction','Hispanic','White','Black','White','Native','Production','OtherTransp','MeanCommute','Asian','Pacific','Professional','WorkAtHome'], axis ="columns")
    )

    df2 = (
        df1
        .loc[(df1['State'] == 'Florida') | (df1['State'] == 'Texas')|(df1['State'] == 'California')|(df1['State'] == 'New York')]
        .reset_index()
        .drop(['index'], axis=1) 
    )
  
    return df2

# %%
load_and_process("acs2017_county_data.csv")
# Out:
#      CountyId       State            County  TotalPop     Men   Women  Income  \
# 0        6001  California    Alameda County   1629615  799649  829966   85743
# 1        6003  California     Alpine County      1203     664     539   63438
# 2        6005  California     Amador County     37306   20005   17301   60636
# 3        6007  California      Butte County    225207  111587  113620   46516
# 4        6009  California  Calaveras County     45057   22292   22765   54800
# ..        ...         ...               ...       ...     ...     ...     ...
# 436     48499       Texas       Wood County     43315   21523   21792   48038
# 437     48501       Texas     Yoakum County      8481    4286    4195   62500
# 438     48503       Texas      Young County     18166    8922    9244   46351
# 439     48505       Texas     Zapata County     14415    7190    7225   34550
# 440     48507       Texas     Zavala County     12152    6163    5989   25988
#
#      IncomeErr  IncomePerCap  IncomePerCapErr  Poverty  ChildPoverty  \
# 0          940         41363              335     11.3          13.0
# 1         4535         27448             6258     19.8          17.3
# 2         2765         29628             1631     10.6          20.3
# 3         1130         26304              656     20.5          21.5
# 4         3529         31652             1278     12.8          18.9
# ..         ...           ...              ...      ...           ...
# 436       3129         25955             1664     13.3          22.0
# 437       8792         23681             2553     12.3          14.6
# 438       3907         25661             2290     16.5          25.9
# 439       6700         17817             3167     34.1          48.0
# 440       5009         13105             1562     36.2          56.3
#
#      Employed  PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment
# 0      826310         79.3        13.2           7.3         0.1           6.0
# 1         374         58.6        30.2          11.2         0.0          14.6
# 2       13444         63.9        21.0          14.7         0.4           9.3
# 3       93439         72.8        17.2           9.7         0.4           9.1
# 4       16721         67.6        18.2          13.7         0.4           7.1
# ..        ...          ...         ...           ...         ...           ...
# 436     15960         78.4        14.1           7.1         0.4           7.8
# 437      3755         71.7        17.5          10.7         0.1           7.5
# 438      8248         69.8        17.1          11.9         1.2           4.5
# 439      5146         66.0        21.0          12.6         0.4          12.4
# 440      4397         73.9        21.2           4.9         0.1          10.1
#
# [441 rows x 18 columns]
